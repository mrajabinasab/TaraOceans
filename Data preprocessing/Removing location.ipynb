# %%
import pandas as pd

# %%
df = pd.read_csv('TARA_mhws_3.csv')
df
# Out:
#       ammonium  ammonium std   nitrite  nitrite std   nitrate    age  \
# 0     0.017782      0.003814  0.033199     0.021603  0.006594  120.0
# 1     0.017782      0.003814  0.033199     0.021603  0.006594  120.0
# 2     0.019857      0.004334  0.022540     0.003445  0.004371  120.0
# 3     0.019621      0.001549  0.049836     0.016420  0.008997  120.0
# 4     0.019621      0.001549  0.049836     0.016420  0.008997  120.0
# ...        ...           ...       ...          ...       ...    ...
# 4061       NaN           NaN       NaN          NaN       NaN    NaN
# 4062       NaN           NaN       NaN          NaN       NaN    NaN
# 4063       NaN           NaN       NaN          NaN       NaN    NaN
# 4064       NaN           NaN       NaN          NaN       NaN    NaN
# 4065       NaN           NaN       NaN          NaN       NaN    NaN
#
#       depth bathy                                        bg province  \
# ...

# %%
no_loc = df.drop(['latitude', 'latitude.1', 'latitude.2', 'latitude.3', 'longitude', 'longitude.1', 'longitude.2', 'longitude.3'], axis = 1)
no_loc
# Out:
#       ammonium  ammonium std   nitrite  nitrite std   nitrate    age  \
# 0     0.017782      0.003814  0.033199     0.021603  0.006594  120.0
# 1     0.017782      0.003814  0.033199     0.021603  0.006594  120.0
# 2     0.019857      0.004334  0.022540     0.003445  0.004371  120.0
# 3     0.019621      0.001549  0.049836     0.016420  0.008997  120.0
# 4     0.019621      0.001549  0.049836     0.016420  0.008997  120.0
# ...        ...           ...       ...          ...       ...    ...
# 4061       NaN           NaN       NaN          NaN       NaN    NaN
# 4062       NaN           NaN       NaN          NaN       NaN    NaN
# 4063       NaN           NaN       NaN          NaN       NaN    NaN
# 4064       NaN           NaN       NaN          NaN       NaN    NaN
# 4065       NaN           NaN       NaN          NaN       NaN    NaN
#
#       depth bathy                                        bg province  \
# ...

# %%
no_loc.to_csv('no_loc.csv', index = False)

# %%
df_1 = pd.read_csv('no_loc.csv')
df_1
# Out:
#       ammonium  ammonium std   nitrite  nitrite std   nitrate    age  \
# 0     0.017782      0.003814  0.033199     0.021603  0.006594  120.0
# 1     0.017782      0.003814  0.033199     0.021603  0.006594  120.0
# 2     0.019857      0.004334  0.022540     0.003445  0.004371  120.0
# 3     0.019621      0.001549  0.049836     0.016420  0.008997  120.0
# 4     0.019621      0.001549  0.049836     0.016420  0.008997  120.0
# ...        ...           ...       ...          ...       ...    ...
# 4061       NaN           NaN       NaN          NaN       NaN    NaN
# 4062       NaN           NaN       NaN          NaN       NaN    NaN
# 4063       NaN           NaN       NaN          NaN       NaN    NaN
# 4064       NaN           NaN       NaN          NaN       NaN    NaN
# 4065       NaN           NaN       NaN          NaN       NaN    NaN
#
#       depth bathy                                        bg province  \
# ...

# %%
no_loco = df_1.drop(['u', 'v', 'distance closest', 'distance', 'depth bathy'], axis = 1).drop_duplicates(inplace = False)
no_loco
# Out:
#       ammonium  ammonium std   nitrite  nitrite std   nitrate    age  \
# 0     0.017782      0.003814  0.033199     0.021603  0.006594  120.0
# 1     0.017782      0.003814  0.033199     0.021603  0.006594  120.0
# 2     0.019857      0.004334  0.022540     0.003445  0.004371  120.0
# 3     0.019621      0.001549  0.049836     0.016420  0.008997  120.0
# 4     0.019621      0.001549  0.049836     0.016420  0.008997  120.0
# ...        ...           ...       ...          ...       ...    ...
# 4061       NaN           NaN       NaN          NaN       NaN    NaN
# 4062       NaN           NaN       NaN          NaN       NaN    NaN
# 4063       NaN           NaN       NaN          NaN       NaN    NaN
# 4064       NaN           NaN       NaN          NaN       NaN    NaN
# 4065       NaN           NaN       NaN          NaN       NaN    NaN
#
#                                             bg province  chlorophyll a  \
# ...

# %%
no_loco.to_csv('no_loc_updated.csv', index = False)
